# %% [markdown]
# <a href="https://colab.research.google.com/github/RubenQuispe/Machine-Learning-con-Python-001/blob/master/Casos%20pr%C3%A1cticos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EVALUACIÓN PARCIAL PART 1 CISCO PYTHON
# ## M.Sc. Rubén Quispe

# %%
lst = [1,2]
for v in range (2):
  lst.insert(-1,lst[v])

print(lst)
# Out:
# [1, 1, 1, 2]

# %% [markdown]
# # 2. El significado de un argumento posicional esta determinado por: su posicion dentro de a lista

# %%
nums =[1,2,3]
vals=nums
# 3. vals es mas largo que nums
# 4. !=

# %%
# 5 
def func1 (a):
  return None

def func2(a):
  return func1 (a)* func1(a)

print(func2(2))
# provoca un error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-cb542110adf4> in <module>()
#       5   return func1 (a)* func1(a)
#       6
# ----> 7 print(func2(2))
#       8 # provoca un error
#
# <ipython-input-6-cb542110adf4> in func2(a)
#       3
#       4 def func2(a):
# ----> 5   return func1 (a)* func1(a)
#       6
#       7 print(func2(2))
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'NoneType'

# %%
# 6
1//2
# Out:
# 0

# %%
# 7
def func(a,b):
  return b ** a

print (func(b=2,2))
# error
# Out:
#   File "<ipython-input-29-c0bc58619789>", line 5
#     print (func(b=2,2))
#                    ^
# SyntaxError: positional argument follows keyword argument

# %%
# 8 
z=0
y=10
x=y<z and z>y or y >z and z<y
x
# 9 IN
# Out:
# True

# %%
# 10
list =[x * x for x in range (5)]
def fun(lst):
  del lst[lst[2]]
  return lst
print(fun(list))
# Out:
# [0, 1, 4, 9]

# %%
# 11
x= 1
y = 2
x,y,z =x,x,y
z,y,z=x,y,z
print(x,y,z)
# Out:
# 1 1 2

# %%
# 12
a= 1
b=0
a= a^b
b= a^b
a= a^b
print (a,b)
# Out:
# 0 1

# %%
# 13
def fun(x):
  if x%2 ==0:
    return 1
  else:
    return 2
print(fun(fun(2)))
# Out:
# 2

# %%
# 14 vals es mas largo que nums
nums = [1,2,3]
vals=nums
del vals[:]

# %%
# 15
x = int (input())
y = int (input())
x = x % y
x = x % y
y = y % x
print(y)
# Out:
# 3
# 2
# 0

# %%
# 16
y =input()
x= input()
print(x+y)
# Out:
# 3
# 6
# 63

# %%
# 17 
print("a", 'b','c',sep='sep')
# Out:
# asepbsepc

# %%
# 18 
x= 1//5 + 1/5
print(x)
# Out:
# 0.2

# %%
# 19 es ilegal
tuple[1] = tuple[1]+tuple[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-6de0fb0e0dad> in <module>()
#       1
#       2 # 19
# ----> 3 tuple[1] = tuple[1]+tuple[0]
#
# TypeError: 'type' object is not subscriptable

# %%
# 20
x = float (input())
y = float(input())
print(y **(1/x))
# Out:
# 2
# 4
# 2.0

# %%
# 21 
dct ={'uno':'dos', 'tres':'uno', 'dos':'tres'}
v= dct['tres']
for k in range (len(dct)):
  v = dct[v]
print(v)
# Out:
# uno

# %%
# 22
lst = [i for i in range(-1, -2)]
lst
# Out:
# []

# %%
# 23
def fun(a,b, c=0):
# fun (a=1,b=0, c=0)
# Out:
#   File "<ipython-input-44-1c12662f106d>", line 2
#     def fun (a=1,b=0, c=0)
#                           ^
# SyntaxError: invalid syntax

# %%
# 24
def fun (x,y):
  if x ==y:
    return x
  else:
    return fun(x, y-1)
print(fun(0,3))
# Out:
# 0

# %%
# 25 
i= 0
while i <i + 2:
  i += 1
  print("*")
else:
  print("*")
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# ...

# %%
# 26
tup = (1, 2,4,8)
tup = tup[-2:-1]
tup = tup[-1]
print(tup)
# Out:
# 4

# %%
# 27 
dd ={"1":"0", "0":"1"}
for x in dd.vals():
  print(x,end="")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-ec14b615793d> in <module>()
#       1 # 27
#       2 dd ={"1":"0", "0":"1"}
# ----> 3 for x in dd.vals():
#       4   print(x,end="")
#
# AttributeError: 'dict' object has no attribute 'vals'

# %%
# 28 
dct = {}
dct['1'] = (1,2)
dct['2'] = (2,1)

for x in dct.keys():
  print(dct[x][1], end='')
# Out:
# 21

# %%
# 29 
def fun(inp =2, out=3):
  return inp * out

print(fun(out=2))
# Out:
# 4

# %%
# 30
lst =[[x for x in range(3)] for y in range (3)]
for r in range(3):
  for c in range(3):
    if lst[r][c]%2!=0:
      print('#')
# Out:
# #
# #
# #

# %%
assert var == 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-f359bff12d43> in <module>()
# ----> 1 assert var == 0
#
# NameError: name 'var' is not defined

# %%
x = '\''
print(len(x))
# Out:
# 1

# %%
print (ord('c')- ord('a'))
# Out:
# 2

# %%
print(chr(ord('z')-2))
# Out:
# x

# %%
print(3 * 'abc' + 'xyz')
# Out:
# abcabcabcxyz

# %%
# 19
print('Mike'> 'Mikey')
# Out:
# False

# %%
# 20
print(float("1, 3"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-71857ec1e96a> in <module>()
#       1 # 20
# ----> 2 print(float("1, 3"))
#
# ValueError: could not convert string to float: '1, 3'

# %%
def o (p):
  def q():
    return '*' *p
  return q
r =o (1)
s= o (2)
print(r()+s())
# Out:
# ***

# %%
# PLANILLA 
horas = int(input('horas laboradas: '))
tarifa = float(input("tarifa por horas: "))
print ("total a pagar:S/ ", horas*tarifa)
# Out:
# horas laboradas: 2
# tarifa por horas: 24
# total a pagar:S/  48.0

# %%
# DISTANCIA DE UN MOVIL 
velocidad = float(input("Velocidad del objeto en m/s: "))
tiempo = float(input("tiempo de movimiento en s:"))
print ("Distancia:  ", velocidad*tiempo, "metros")
# Out:
# Velocidad del objeto en m/s: 46
# tiempo de movimiento en s:3
# Distancia:   138.0 metros

# %%
v=34
t=50
d=v*t
print("la distancia es: ", d)
# Out:
# la distancia es:  1700

# %%
# caso 3 
Nota1 = float (input("Nota1: "))
Nota2 = float(input ("")
